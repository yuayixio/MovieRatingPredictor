# %% [markdown]
# # Cleaning of OMDB Database

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('../data/preprocessed/movies_id_updated.csv', sep=',')
ratings = pd.read_csv('../data/raw/ratings.csv', sep=',')
omdb = pd.read_csv('../data/raw/omdb_total.csv')

# %%
movies = movies.rename(columns = {'id':'movieID'})
rated_movies = pd.merge(movies, ratings, how = 'outer', on = 'movieID')

# %%
rated_movies.head()
# Out:
#    movieID      title     imdbID          spanishTitle  \
# 0        1  Toy story  tt0114709  Toy story (juguetes)
# 1        1  Toy story  tt0114709  Toy story (juguetes)
# 2        1  Toy story  tt0114709  Toy story (juguetes)
# 3        1  Toy story  tt0114709  Toy story (juguetes)
# 4        1  Toy story  tt0114709  Toy story (juguetes)
#
#                                       imdbPictureURL    year       rtID  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 1  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 2  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 3  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 4  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
#
#                                         rtPictureURL  user_id  rating
# 0  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 1  http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5
# 2  http://content7.flixster.com/movie/10/93/63/10...    336.0     4.5
# 3  http://content7.flixster.com/movie/10/93/63/10...   1087.0     3.5
# 4  http://content7.flixster.com/movie/10/93/63/10...   1598.0     4.0

# %%
omdb.head()
# Out:
#    Unnamed: 0                        Title  Year  Rated     Released  Runtime  \
# 0           0                    Toy Story  1995      G  22 Nov 1995   81 min
# 1           1                      Jumanji  1995     PG  15 Dec 1995  104 min
# 2           2               Grumpy Old Men  1993  PG-13  25 Dec 1993  103 min
# 3           3            Waiting to Exhale  1995      R  22 Dec 1995  124 min
# 4           4  Father of the Bride Part II  1995     PG  08 Dec 1995  106 min
#
#                                            Genre         Director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                         Comedy, Drama, Romance    Donald Petrie
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               Writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2                                Mark Steven Johnson
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               Actors  ... Production Website  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney  ...        NaN     NaN
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...  ...        NaN     NaN
# 2  Jack Lemmon, Walter Matthau, Ann-Margret, Burg...  ...        NaN     NaN
# 3  Whitney Houston, Angela Bassett, Loretta Devin...  ...        NaN     NaN
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...  ...        NaN     NaN
#
#   Response Internet Movie Database Rotten Tomatoes  Metacritic  totalSeasons  \
# 0     True                  8.3/10            100%      95/100           NaN
# 1     True                  7.0/10             54%      39/100           NaN
# 2     True                  7.0/10             63%      53/100           NaN
# 3     True                  5.9/10             56%         NaN           NaN
# 4     True                  6.0/10             48%      49/100           NaN
#
#   Season Episode seriesID
# 0    NaN     NaN      NaN
# 1    NaN     NaN      NaN
# 2    NaN     NaN      NaN
# 3    NaN     NaN      NaN
# 4    NaN     NaN      NaN
#
# [5 rows x 32 columns]

# %%
omdb.describe()
# Out:
#          Unnamed: 0    Metascore    imdbRating  totalSeasons     Season  \
# count  10192.000000  6013.000000  10188.000000     68.000000   8.000000
# mean    5095.500000    57.963745      6.591932      4.000000  11.125000
# std     2942.321306    18.512885      1.019839      4.926323   7.472569
# min        0.000000     1.000000      1.500000      1.000000   1.000000
# 25%     2547.750000    45.000000      6.000000      1.000000   4.500000
# 50%     5095.500000    59.000000      6.700000      2.000000  12.000000
# 75%     7643.250000    71.000000      7.300000      5.000000  17.500000
# max    10191.000000   100.000000      9.400000     22.000000  20.000000
#
#          Episode
# count   8.000000
# mean    6.375000
# std     5.125218
# min     0.000000
# 25%     1.000000
# 50%     7.000000
# 75%    11.250000
# max    12.000000

# %%
# Out:
# Unnamed: 0
# Title
# Year
# Rated
# Released
# Runtime
# Genre
# Director
# Writer
# Actors
# Plot
# Language
# Country
# Awards
# Poster
# Metascore
# imdbRating
# imdbVotes
# imdbID
# Type
# DVD
# BoxOffice
# Production
# Website
# Response
# Internet Movie Database
# Rotten Tomatoes
# Metacritic
# totalSeasons
# Season
# Episode
# seriesID

# %%
omdb = omdb.drop(['Production','Website','totalSeasons','Season','Episode','seriesID','Type','BoxOffice','DVD','Response','Poster'],axis=1)

# %%
for col in omdb.columns: 
    print(col)
# Out:
# Unnamed: 0
# Title
# Year
# Rated
# Released
# Runtime
# Genre
# Director
# Writer
# Actors
# Plot
# Language
# Country
# Awards
# Metascore
# imdbRating
# imdbVotes
# imdbID
# Internet Movie Database
# Rotten Tomatoes
# Metacritic

# %%
omdb.head()
# Out:
#    Unnamed: 0                        Title  Year  Rated     Released  Runtime  \
# 0           0                    Toy Story  1995      G  22 Nov 1995   81 min
# 1           1                      Jumanji  1995     PG  15 Dec 1995  104 min
# 2           2               Grumpy Old Men  1993  PG-13  25 Dec 1993  103 min
# 3           3            Waiting to Exhale  1995      R  22 Dec 1995  124 min
# 4           4  Father of the Bride Part II  1995     PG  08 Dec 1995  106 min
#
#                                            Genre         Director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                         Comedy, Drama, Romance    Donald Petrie
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               Writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2                                Mark Steven Johnson
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               Actors  ...         Language  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney  ...          English
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...  ...  English, French
# 2  Jack Lemmon, Walter Matthau, Ann-Margret, Burg...  ...          English
# 3  Whitney Houston, Angela Bassett, Loretta Devin...  ...          English
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...  ...          English
#
#   Country                                             Awards Metascore  \
# 0     USA  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0
# 1     USA                           4 wins & 11 nominations.      39.0
# 2     USA                              1 win & 1 nomination.      53.0
# 3     USA                           9 wins & 10 nominations.       NaN
# 4     USA  Nominated for 1 Golden Globe. Another 1 win & ...      49.0
#
#    imdbRating  imdbVotes     imdbID Internet Movie Database Rotten Tomatoes  \
# 0         8.3    852,896  tt0114709                  8.3/10            100%
# 1         7.0    294,340  tt0113497                  7.0/10             54%
# 2         7.0     41,401  tt0107050                  7.0/10             63%
# 3         5.9      9,222  tt0114885                  5.9/10             56%
# 4         6.0     33,005  tt0113041                  6.0/10             48%
#
#   Metacritic
# 0     95/100
# 1     39/100
# 2     53/100
# 3        NaN
# 4     49/100
#
# [5 rows x 21 columns]

# %%
movie_data = pd.merge(rated_movies, omdb, how = 'outer', on = 'imdbID')

# %%
movie_data = movie_data.drop(['Unnamed: 0'],axis=1)

# %%
movie_data.isna().sum()
# Out:
# movieID                        5
# title                          5
# imdbID                         0
# spanishTitle                   5
# imdbPictureURL              2230
# year                         385
# rtID                       15728
# rtPictureURL                 385
# user_id                      151
# rating                       151
# Title                        270
# Year                         270
# Rated                       4401
# Released                     958
# Runtime                      287
# Genre                        282
# Director                    3016
# Writer                      6282
# Actors                       531
# Plot                         506
# Language                     563
# Country                      324
# Awards                     48118
# Metascore                  94138
# imdbRating                   274
# imdbVotes                   1903
# Internet Movie Database      274
# Rotten Tomatoes            32420
# Metacritic                 94132
# dtype: int64

# %%
#Remove '%' and convert to float
movie_data['Rotten Tomatoes'] = movie_data['Rotten Tomatoes'].str.replace(r'\D', '').astype(float)

# %%
movie_data.iloc[1, 27]
# Out:
# 100.0

# %%
movie_data['Rotten Tomatoes'].describe()
# Out:
# count    970054.000000
# mean         71.665898
# std          23.948137
# min           0.000000
# 25%          57.000000
# 50%          79.000000
# 75%          91.000000
# max         100.000000
# Name: Rotten Tomatoes, dtype: float64

# %%
# Convert 'Rotten Tomatoes Score to [0.5 ; 5]'
# Set to 0.5 if a 0 was given as score -> leads to a slightly better score after conversion

movie_data['Rotten Tomatoes'] = movie_data['Rotten Tomatoes'].apply(lambda x: x/20).apply(lambda x: 0.5 if x < 0.5 else x)

# %%
#Replace '/10' and convert to float
movie_data['Internet Movie Database'] = movie_data['Internet Movie Database'].str.replace(r'/10', '').astype(float)

# %%
movie_data['Internet Movie Database']
# Out:
# 0          8.3
# 1          8.3
# 2          8.3
# 3          8.3
# 4          8.3
#           ...
# 1002469    7.2
# 1002470    NaN
# 1002471    NaN
# 1002472    NaN
# 1002473    NaN
# Name: Internet Movie Database, Length: 1002474, dtype: float64

# %%
movie_data['Internet Movie Database'].describe()
# Out:
# count    1.002200e+06
# mean     7.141970e+00
# std      9.221005e-01
# min      1.500000e+00
# 25%      6.600000e+00
# 50%      7.300000e+00
# 75%      7.800000e+00
# max      9.400000e+00
# Name: Internet Movie Database, dtype: float64

# %%
# Convert 'Internet Movie Database' Score to [0.5 ; 5]'
# The Internet Movie Database Score is already an average which lies in [1,10]
# Doing conversion based on this assumption -> no movie gets 0.5 as score (since there was no 1)

movie_data['Internet Movie Database'] = movie_data['Internet Movie Database'].apply(lambda x: x/2).apply(lambda x: 0.5 if x < 0.5 else x)

# %%
# Convert 'imdbRating' Score to [0.5 ; 5]'
# imdbRating seems to be the same as 'Internet Movie Database' Score -> keep in mind
movie_data['imdbRating'] = movie_data['imdbRating'].apply(lambda x: x/2).apply(lambda x: 0.5 if x < 0.5 else x)

# %%
#Replace '/100' and convert to float
movie_data['Metacritic'] = movie_data['Metacritic'].str.replace(r'/100', '').astype(float)

# %%
movie_data['Metacritic']
# Out:
# 0          95.0
# 1          95.0
# 2          95.0
# 3          95.0
# 4          95.0
#            ...
# 1002469    69.0
# 1002470     NaN
# 1002471     NaN
# 1002472     NaN
# 1002473     NaN
# Name: Metacritic, Length: 1002474, dtype: float64

# %%
movie_data['Metacritic'].describe()
# Out:
# count    908342.000000
# mean         65.623761
# std          17.431752
# min           1.000000
# 25%          54.000000
# 50%          66.000000
# 75%          79.000000
# max         100.000000
# Name: Metacritic, dtype: float64

# %%
# Convert 'Metacritic' Score to [0.5 ; 5]'

movie_data['Metacritic'] = movie_data['Metacritic'].apply(lambda x: x/20).apply(lambda x: 0.5 if x < 0.5 else x)

# %%
movie_data['Metascore'].describe()
# Out:
# count    908336.000000
# mean         65.623679
# std          17.431780
# min           1.000000
# 25%          54.000000
# 50%          66.000000
# 75%          79.000000
# max         100.000000
# Name: Metascore, dtype: float64

# %%
# Convert 'Metascore'
movie_data['Metascore'] = movie_data['Metascore'].apply(lambda x: x/20).apply(lambda x: 0.5 if x < 0.5 else x)

# %%
# Convert runtime to float and remove 'min'
movie_data['Runtime'] = movie_data['Runtime'].str.replace(r'min', '').astype(float)

# %%
movie_data['Runtime'].head()
# Out:
# 0    81.0
# 1    81.0
# 2    81.0
# 3    81.0
# 4    81.0
# Name: Runtime, dtype: float64

# %%
#Convert date into float
#Not 100% sure if this is entirely correct but stackoverflow said so and it seems right
movie_data['Released'] = pd.to_datetime(movie_data['Released']).dt.year.astype(float)

# %%
movie_data['Released'].describe()
# Out:
# count    1.001516e+06
# mean     1.992629e+07
# std      1.490312e+05
# min      1.903121e+07
# 25%      1.988080e+07
# 50%      1.997071e+07
# 75%      2.003021e+07
# max      2.019080e+07
# Name: Released, dtype: float64

# %%
movie_data.dtypes
# Out:
# movieID                    float64
# title                       object
# imdbID                      object
# spanishTitle                object
# imdbPictureURL              object
# year                       float64
# rtID                        object
# rtPictureURL                object
# user_id                    float64
# rating                     float64
# Title                       object
# Year                        object
# Rated                       object
# Released                   float64
# Runtime                    float64
# Genre                       object
# Director                    object
# Writer                      object
# Actors                      object
# Plot                        object
# Language                    object
# Country                     object
# Awards                      object
# Metascore                  float64
# imdbRating                 float64
# imdbVotes                   object
# Internet Movie Database    float64
# Rotten Tomatoes            float64
# Metacritic                 float64
# dtype: object

# %%
movie_data['Title'].isna().sum()
# Out:
# 270

# %%
# Remove NaN 'titles' - (Rows of NaN titles are almost completely NaN)
man_rows = pd.DataFrame()
man_rows = movie_data.index[movie_data['title'].isnull()]
print(man_rows)
for i in man_rows:
    movie_data = movie_data.drop([i], axis=0)
# Out:
# Int64Index([1002469, 1002470, 1002471, 1002472, 1002473], dtype='int64')

# %%
movie_data['title'].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1002464    False
# 1002465    False
# 1002466    False
# 1002467    False
# 1002468    False
# Name: title, Length: 1002469, dtype: bool

# %%
movie_data
# Out:
#          movieID                    title     imdbID             spanishTitle  \
# 0            1.0                Toy story  tt0114709     Toy story (juguetes)
# 1            1.0                Toy story  tt0114709     Toy story (juguetes)
# 2            1.0                Toy story  tt0114709     Toy story (juguetes)
# 3            1.0                Toy story  tt0114709     Toy story (juguetes)
# 4            1.0                Toy story  tt0114709     Toy story (juguetes)
# ...          ...                      ...        ...                      ...
# 1002464  65126.0                    Choke  tt1024715                    Choke
# 1002465  65126.0                    Choke  tt1024715                    Choke
# 1002466  65133.0  Blackadder Back & Forth  tt0212579  Blackadder Back & Forth
# 1002467  65133.0  Blackadder Back & Forth  tt0212579  Blackadder Back & Forth
# 1002468  65133.0  Blackadder Back & Forth  tt0212579  Blackadder Back & Forth
#
#                                             imdbPictureURL    year  \
# 0        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 1        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 2        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 3        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 4        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# ...                                                    ...     ...
# 1002464  http://ia.media-imdb.com/images/M/MV5BMTMxMDI4...  2008.0
# 1002465  http://ia.media-imdb.com/images/M/MV5BMTMxMDI4...  2008.0
# 1002466  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999.0
# 1002467  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999.0
# 1002468  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999.0
#
#                           rtID  \
# 0                    toy_story
# 1                    toy_story
# 2                    toy_story
# 3                    toy_story
# 4                    toy_story
# ...                        ...
# 1002464                  choke
# 1002465                  choke
# 1002466  blackadder-back-forth
# 1002467  blackadder-back-forth
# 1002468  blackadder-back-forth
#
#                                               rtPictureURL  user_id  rating  \
# 0        http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 1        http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 2        http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 3        http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5
# 4        http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5
# ...                                                    ...      ...     ...
# 1002464  http://content6.flixster.com/movie/10/85/09/10...   1273.0     3.0
# 1002465  http://content6.flixster.com/movie/10/85/09/10...    599.0     3.5
# 1002466  http://content7.flixster.com/movie/34/10/69/34...   1059.0     4.0
# 1002467  http://content7.flixster.com/movie/34/10/69/34...    480.0     5.0
# 1002468  http://content7.flixster.com/movie/34/10/69/34...   1228.0     3.0
#
#          ...                                               Plot Language  \
# 0        ...  A cowboy doll is profoundly threatened and jea...  English
# 1        ...  A cowboy doll is profoundly threatened and jea...  English
# 2        ...  A cowboy doll is profoundly threatened and jea...  English
# 3        ...  A cowboy doll is profoundly threatened and jea...  English
# 4        ...  A cowboy doll is profoundly threatened and jea...  English
# ...      ...                                                ...      ...
# 1002464  ...  A sex-addicted con-man pays for his mother's h...  English
# 1002465  ...  A sex-addicted con-man pays for his mother's h...  English
# 1002466  ...  At a New Millennium Eve party, Blackadder and ...  English
# 1002467  ...  At a New Millennium Eve party, Blackadder and ...  English
# 1002468  ...  At a New Millennium Eve party, Blackadder and ...  English
#
#         Country                                             Awards  Metascore  \
# 0           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75
# 1           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75
# 2           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75
# 3           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75
# 4           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75
# ...         ...                                                ...        ...
# 1002464     USA                            2 wins & 7 nominations.       2.35
# 1002465     USA                            2 wins & 7 nominations.       2.35
# 1002466      UK                                      1 nomination.        NaN
# 1002467      UK                                      1 nomination.        NaN
# 1002468      UK                                      1 nomination.        NaN
#
#         imdbRating imdbVotes Internet Movie Database Rotten Tomatoes  \
# 0             4.15   852,896                    4.15            5.00
# 1             4.15   852,896                    4.15            5.00
# 2             4.15   852,896                    4.15            5.00
# 3             4.15   852,896                    4.15            5.00
# 4             4.15   852,896                    4.15            5.00
# ...            ...       ...                     ...             ...
# 1002464       3.20    31,058                    3.20            2.75
# 1002465       3.20    31,058                    3.20            2.75
# 1002466       3.85    13,510                    3.85             NaN
# 1002467       3.85    13,510                    3.85             NaN
# 1002468       3.85    13,510                    3.85             NaN
#
#         Metacritic
# 0             4.75
# 1             4.75
# 2             4.75
# 3             4.75
# 4             4.75
# ...            ...
# 1002464       2.35
# 1002465       2.35
# 1002466        NaN
# 1002467        NaN
# 1002468        NaN
#
# [1002469 rows x 29 columns]

# %% [markdown]
# # TODO:
# -Remove all other useless rows (with too many NaNs?)
#
# -Remove double/multiple ratings of same users
#
# -Check if all movies are merged under the same omdbID
#
# -Print out data into ../data/preprocessed folder
#
# -Build dataframe/csv with average rating for each omdbID -> DONE

# %%
# Remove Duplicated Ratings

# %%
# Export
# Everyone can run this command themselves - i won't check in this file (0,7gb) (added to .gitignore)

movie_data.to_csv('../data/preprocessed/omdb_cleaned.csv')

# %% [markdown]
# # Build csv with average rating for each omdbID

# %%
movie_data.head()
# Out:
#    movieID      title     imdbID          spanishTitle  \
# 0      1.0  Toy story  tt0114709  Toy story (juguetes)
# 1      1.0  Toy story  tt0114709  Toy story (juguetes)
# 2      1.0  Toy story  tt0114709  Toy story (juguetes)
# 3      1.0  Toy story  tt0114709  Toy story (juguetes)
# 4      1.0  Toy story  tt0114709  Toy story (juguetes)
#
#                                       imdbPictureURL    year       rtID  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 1  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 2  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 3  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 4  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
#
#                                         rtPictureURL  user_id  rating  ...  \
# 0  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0  ...
# 1  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0  ...
# 2  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0  ...
# 3  http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5  ...
# 4  http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5  ...
#
#                                                 Plot Language Country  \
# 0  A cowboy doll is profoundly threatened and jea...  English     USA
# 1  A cowboy doll is profoundly threatened and jea...  English     USA
# 2  A cowboy doll is profoundly threatened and jea...  English     USA
# 3  A cowboy doll is profoundly threatened and jea...  English     USA
# 4  A cowboy doll is profoundly threatened and jea...  English     USA
#
#                                               Awards  Metascore imdbRating  \
# 0  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75       4.15
# 1  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75       4.15
# 2  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75       4.15
# 3  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75       4.15
# 4  Nominated for 3 Oscars. Another 27 wins & 20 n...       4.75       4.15
#
#   imdbVotes Internet Movie Database Rotten Tomatoes Metacritic
# 0   852,896                    4.15             5.0       4.75
# 1   852,896                    4.15             5.0       4.75
# 2   852,896                    4.15             5.0       4.75
# 3   852,896                    4.15             5.0       4.75
# 4   852,896                    4.15             5.0       4.75
#
# [5 rows x 29 columns]

# %%
average_ratings = movie_data

# %%
average_ratings = average_ratings.drop(['spanishTitle','imdbPictureURL','Year','year','Rated','Released','Runtime','Genre','Title','Director','Writer','Actors','rtID','rtPictureURL','Plot','Language','Country','Awards','imdbVotes'],axis=1)

# %%
average_ratings.describe()
# Out:
#             movieID       user_id        rating      Metascore    imdbRating  \
# count  1.002469e+06  1.002323e+06  1.002323e+06  908335.000000  1.002199e+06
# mean   8.934601e+03  6.928460e+02  3.439775e+00       3.281309  3.570985e+00
# std    1.464392e+04  4.989834e+02  9.981290e-01       0.871166  4.610505e-01
# min    1.000000e+00  0.000000e+00  5.000000e-01       0.500000  7.500000e-01
# 25%    1.370000e+03  2.740000e+02  3.000000e+00       2.700000  3.300000e+00
# 50%    3.274000e+03  5.950000e+02  3.500000e+00       3.300000  3.650000e+00
# 75%    6.642000e+03  1.045000e+03  4.000000e+00       3.950000  3.900000e+00
# max    6.513300e+04  2.112000e+03  5.000000e+00       5.000000  4.700000e+00
#
#        Internet Movie Database  Rotten Tomatoes     Metacritic
# count             1.002199e+06    970050.000000  908341.000000
# mean              3.570985e+00         3.586193       3.281314
# std               4.610505e-01         1.189517       0.871165
# min               7.500000e-01         0.500000       0.500000
# 25%               3.300000e+00         2.850000       2.700000
# 50%               3.650000e+00         3.950000       3.300000
# 75%               3.900000e+00         4.550000       3.950000
# max               4.700000e+00         5.000000       5.000000

# %%
average_ratings = average_ratings.sort_values(by=['imdbID'])

# %%
avg = average_ratings.groupby('imdbID') ['rating'].mean()
average_ratings = average_ratings.join(avg, on='imdbID', rsuffix='Avg')

imdb_avg = average_ratings.groupby('imdbID')['imdbRating'].mean()
average_ratings = average_ratings.join(imdb_avg, on='imdbID', rsuffix=' Avg')

rt_avg = average_ratings.groupby('imdbID')['Rotten Tomatoes'].mean()
average_ratings = average_ratings.join(rt_avg, on='imdbID', rsuffix='Avg')

iMB_avg = average_ratings.groupby('imdbID')['Internet Movie Database'].mean()
average_ratings = average_ratings.join(iMB_avg, on='imdbID', rsuffix=' Avg')

metascore_avg = average_ratings.groupby('imdbID')['Metascore'].mean()
average_ratings = average_ratings.join(metascore_avg, on='imdbID', rsuffix=' Avg')

metacritic_avg = average_ratings.groupby('imdbID')['Metacritic'].mean()
average_ratings = average_ratings.join(metacritic_avg, on='imdbID', rsuffix=' Avg')

# %%
average_ratings.describe()
# Out:
#             movieID       user_id        rating      Metascore    imdbRating  \
# count  1.002469e+06  1.002323e+06  1.002323e+06  908335.000000  1.002199e+06
# mean   8.934601e+03  6.928460e+02  3.439775e+00       3.281309  3.570985e+00
# std    1.464392e+04  4.989834e+02  9.981290e-01       0.871166  4.610505e-01
# min    1.000000e+00  0.000000e+00  5.000000e-01       0.500000  7.500000e-01
# 25%    1.370000e+03  2.740000e+02  3.000000e+00       2.700000  3.300000e+00
# 50%    3.274000e+03  5.950000e+02  3.500000e+00       3.300000  3.650000e+00
# 75%    6.642000e+03  1.045000e+03  4.000000e+00       3.950000  3.900000e+00
# max    6.513300e+04  2.112000e+03  5.000000e+00       5.000000  4.700000e+00
#
#        Internet Movie Database  Rotten Tomatoes     Metacritic     ratingAvg  \
# count             1.002199e+06    970050.000000  908341.000000  1.002354e+06
# mean              3.570985e+00         3.586193       3.281314  3.439773e+00
# std               4.610505e-01         1.189517       0.871165  4.717395e-01
# min               7.500000e-01         0.500000       0.500000  5.000000e-01
# 25%               3.300000e+00         2.850000       2.700000  3.160000e+00
# 50%               3.650000e+00         3.950000       3.300000  3.507042e+00
# 75%               3.900000e+00         4.550000       3.950000  3.788779e+00
# max               4.700000e+00         5.000000       5.000000  5.000000e+00
#
#        imdbRating Avg  Rotten TomatoesAvg  Internet Movie Database Avg  \
# count    1.002199e+06       970050.000000                 1.002199e+06
# mean     3.570985e+00            3.586193                 3.570985e+00
# std      4.610505e-01            1.189517                 4.610505e-01
# min      7.500000e-01            0.500000                 7.500000e-01
# 25%      3.300000e+00            2.850000                 3.300000e+00
# 50%      3.650000e+00            3.950000                 3.650000e+00
# 75%      3.900000e+00            4.550000                 3.900000e+00
# max      4.700000e+00            5.000000                 4.700000e+00
#
#        Metascore Avg  Metacritic Avg
# count  908335.000000   908341.000000
# mean        3.281309        3.281314
# std         0.871166        0.871165
# min         0.500000        0.500000
# 25%         2.700000        2.700000
# 50%         3.300000        3.300000
# 75%         3.950000        3.950000
# max         5.000000        5.000000

# %%
average_ratings = average_ratings.drop(['user_id','rating','rating','Metascore','imdbRating','Internet Movie Database', 'Rotten Tomatoes', 'Metacritic'],axis=1)

# %%
average_ratings = average_ratings.drop_duplicates(subset="imdbID")

# %%
average_ratings.head()
# Out:
#         movieID                                             title     imdbID  \
# 844798   6990.0                           The Great Train Robbery  tt0000439
# 850743   7065.0                             The Birth of a Nation  tt0004972
# 859392   7243.0  Intolerance: Love's Struggle Throughout the Ages  tt0006864
# 886762   8511.0                                     The Immigrant  tt0008133
# 971742  48374.0                                      Otets Sergiy  tt0008395
#
#         ratingAvg  imdbRating Avg  Rotten TomatoesAvg  \
# 844798   3.696970            3.65                5.00
# 850743   3.228261            3.20                4.65
# 859392   3.928571            3.90                4.85
# 886762   3.750000            3.85                 NaN
# 971742   3.000000            3.55                 NaN
#
#         Internet Movie Database Avg  Metascore Avg  Metacritic Avg
# 844798                         3.65            NaN             NaN
# 850743                         3.20            NaN             NaN
# 859392                         3.90           4.95            4.95
# 886762                         3.85            NaN             NaN
# 971742                         3.55            NaN             NaN

# %%
average_ratings.describe()
# Out:
#             movieID    ratingAvg  imdbRating Avg  Rotten TomatoesAvg  \
# count   9423.000000  9308.000000     9413.000000         8177.000000
# mean   12859.453996     3.217871        3.289684            3.122967
# std    17441.096453     0.638007        0.509855            1.383468
# min        1.000000     0.500000        0.750000            0.500000
# 25%     2781.500000     2.869297        3.000000            2.000000
# 50%     5406.000000     3.316283        3.350000            3.400000
# 75%     8663.500000     3.681818        3.650000            4.300000
# max    65133.000000     5.000000        4.700000            5.000000
#
#        Internet Movie Database Avg  Metascore Avg  Metacritic Avg
# count                  9413.000000    5397.000000     5398.000000
# mean                      3.289684       2.890282        2.890469
# std                       0.509855       0.920002        0.920019
# min                       0.750000       0.500000        0.500000
# 25%                       3.000000       2.250000        2.250000
# 50%                       3.350000       2.950000        2.950000
# 75%                       3.650000       3.550000        3.550000
# max                       4.700000       5.000000        5.000000

# %%
# Export
average_ratings.to_csv('../data/preprocessed/average_ratings.csv')
