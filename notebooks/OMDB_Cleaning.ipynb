# %% [markdown]
# # Cleaning of OMDB Database
# ### This is a WIP

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('../data/preprocessed/movies_id_updated.csv', sep=',')
ratings = pd.read_csv('../data/raw/ratings.csv', sep=',')
omdb = pd.read_csv('../data/raw/omdb_total.csv')

# %%
movies = movies.rename(columns = {'id':'movieID'})
rated_movies = pd.merge(movies, ratings, how = 'outer', on = 'movieID')

# %%
rated_movies.head()
# Out:
#    movieID      title     imdbID          spanishTitle  \
# 0        1  Toy story  tt0114709  Toy story (juguetes)
# 1        1  Toy story  tt0114709  Toy story (juguetes)
# 2        1  Toy story  tt0114709  Toy story (juguetes)
# 3        1  Toy story  tt0114709  Toy story (juguetes)
# 4        1  Toy story  tt0114709  Toy story (juguetes)
#
#                                       imdbPictureURL    year       rtID  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 1  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 2  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 3  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 4  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
#
#                                         rtPictureURL  user_id  rating
# 0  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 1  http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5
# 2  http://content7.flixster.com/movie/10/93/63/10...    336.0     4.5
# 3  http://content7.flixster.com/movie/10/93/63/10...   1087.0     3.5
# 4  http://content7.flixster.com/movie/10/93/63/10...   1598.0     4.0

# %%
omdb = omdb.drop(['Production','Website','totalSeasons','Season','Episode','seriesID','Type','BoxOffice','DVD','Response','Poster'],axis=1)

# %%
movie_data = pd.merge(rated_movies, omdb, how = 'outer', on = 'imdbID')

# %%
movie_data = movie_data.drop(['Unnamed: 0'],axis=1)

# %%
movie_data.isna().sum()
# Out:
# movieID                        5
# title                          5
# imdbID                         0
# spanishTitle                   5
# imdbPictureURL              2230
# year                         385
# rtID                       15728
# rtPictureURL                 385
# user_id                      151
# rating                       151
# Title                        270
# Year                         270
# Rated                       4401
# Released                     958
# Runtime                      287
# Genre                        282
# Director                    3016
# Writer                      6282
# Actors                       531
# Plot                         506
# Language                     563
# Country                      324
# Awards                     48118
# Metascore                  94138
# imdbRating                   274
# imdbVotes                   1903
# Internet Movie Database      274
# Rotten Tomatoes            32420
# Metacritic                 94132
# dtype: int64

# %%
#Remove '%' and convert to float
movie_data['Rotten Tomatoes'] = movie_data['Rotten Tomatoes'].str.replace(r'\D', '').astype(float)

# %%
movie_data['Rotten Tomatoes']
# Out:
# 0          100.0
# 1          100.0
# 2          100.0
# 3          100.0
# 4          100.0
#            ...
# 1002469      NaN
# 1002470     23.0
# 1002471     19.0
# 1002472     21.0
# 1002473     16.0
# Name: Rotten Tomatoes, Length: 1002474, dtype: float64

# %%
#Replace '/10' and convert to float
movie_data['Internet Movie Database'] = movie_data['Internet Movie Database'].str.replace(r'/10', '').astype(float)

# %%
movie_data['Internet Movie Database']
# Out:
# 0          8.3
# 1          8.3
# 2          8.3
# 3          8.3
# 4          8.3
#           ...
# 1002469    7.2
# 1002470    NaN
# 1002471    NaN
# 1002472    NaN
# 1002473    NaN
# Name: Internet Movie Database, Length: 1002474, dtype: float64

# %%
#Replace '/100' and convert to float
movie_data['Metacritic'] = movie_data['Metacritic'].str.replace(r'/100', '').astype(float)

# %%
movie_data['Metacritic']
# Out:
# 0          95.0
# 1          95.0
# 2          95.0
# 3          95.0
# 4          95.0
#            ...
# 1002469    69.0
# 1002470     NaN
# 1002471     NaN
# 1002472     NaN
# 1002473     NaN
# Name: Metacritic, Length: 1002474, dtype: float64

# %%
movie_data.head()
# Out:
#    movieID      title     imdbID          spanishTitle  \
# 0      1.0  Toy story  tt0114709  Toy story (juguetes)
# 1      1.0  Toy story  tt0114709  Toy story (juguetes)
# 2      1.0  Toy story  tt0114709  Toy story (juguetes)
# 3      1.0  Toy story  tt0114709  Toy story (juguetes)
# 4      1.0  Toy story  tt0114709  Toy story (juguetes)
#
#                                       imdbPictureURL    year       rtID  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 1  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 2  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 3  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
# 4  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0  toy_story
#
#                                         rtPictureURL  user_id  rating  ...  \
# 0  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0  ...
# 1  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0  ...
# 2  http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0  ...
# 3  http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5  ...
# 4  http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5  ...
#
#                                                 Plot Language Country  \
# 0  A cowboy doll is profoundly threatened and jea...  English     USA
# 1  A cowboy doll is profoundly threatened and jea...  English     USA
# 2  A cowboy doll is profoundly threatened and jea...  English     USA
# 3  A cowboy doll is profoundly threatened and jea...  English     USA
# 4  A cowboy doll is profoundly threatened and jea...  English     USA
#
#                                               Awards Metascore imdbRating  \
# 0  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0        8.3
# 1  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0        8.3
# 2  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0        8.3
# 3  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0        8.3
# 4  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0        8.3
#
#   imdbVotes Internet Movie Database Rotten Tomatoes Metacritic
# 0   852,896                     8.3           100.0       95.0
# 1   852,896                     8.3           100.0       95.0
# 2   852,896                     8.3           100.0       95.0
# 3   852,896                     8.3           100.0       95.0
# 4   852,896                     8.3           100.0       95.0
#
# [5 rows x 29 columns]

# %%
movie_data.shape
# Out:
# (1002474, 29)

# %%
movie_data.dtypes
# Out:
# movieID                    float64
# title                       object
# imdbID                      object
# spanishTitle                object
# imdbPictureURL              object
# year                       float64
# rtID                        object
# rtPictureURL                object
# user_id                    float64
# rating                     float64
# Unnamed: 0                 float64
# Title                       object
# Year                        object
# Rated                       object
# Released                    object
# Runtime                     object
# Genre                       object
# Director                    object
# Writer                      object
# Actors                      object
# Plot                        object
# Language                    object
# Country                     object
# Awards                      object
# Metascore                  float64
# imdbRating                 float64
# imdbVotes                   object
# Internet Movie Database    float64
# Rotten Tomatoes            float64
# Metacritic                 float64
# dtype: object

# %%
movie_data['Title'].isna().sum()
# Out:
# 270

# %%
# Remove NaN 'titles' 
man_rows = pd.DataFrame()
man_rows = movie_data.index[movie_data['title'].isnull()]
print(man_rows)
for i in man_rows:
    movie_data = movie_data.drop([i], axis=0)
# Out:
# Int64Index([1002469, 1002470, 1002471, 1002472, 1002473], dtype='int64')

# %%
movie_data['title'].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1002464    False
# 1002465    False
# 1002466    False
# 1002467    False
# 1002468    False
# Name: title, Length: 1002469, dtype: bool

# %%
movie_data
# Out:
#          movieID                    title     imdbID             spanishTitle  \
# 0            1.0                Toy story  tt0114709     Toy story (juguetes)
# 1            1.0                Toy story  tt0114709     Toy story (juguetes)
# 2            1.0                Toy story  tt0114709     Toy story (juguetes)
# 3            1.0                Toy story  tt0114709     Toy story (juguetes)
# 4            1.0                Toy story  tt0114709     Toy story (juguetes)
# ...          ...                      ...        ...                      ...
# 1002464  65126.0                    Choke  tt1024715                    Choke
# 1002465  65126.0                    Choke  tt1024715                    Choke
# 1002466  65133.0  Blackadder Back & Forth  tt0212579  Blackadder Back & Forth
# 1002467  65133.0  Blackadder Back & Forth  tt0212579  Blackadder Back & Forth
# 1002468  65133.0  Blackadder Back & Forth  tt0212579  Blackadder Back & Forth
#
#                                             imdbPictureURL    year  \
# 0        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 1        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 2        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 3        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# 4        http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995.0
# ...                                                    ...     ...
# 1002464  http://ia.media-imdb.com/images/M/MV5BMTMxMDI4...  2008.0
# 1002465  http://ia.media-imdb.com/images/M/MV5BMTMxMDI4...  2008.0
# 1002466  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999.0
# 1002467  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999.0
# 1002468  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999.0
#
#                           rtID  \
# 0                    toy_story
# 1                    toy_story
# 2                    toy_story
# 3                    toy_story
# 4                    toy_story
# ...                        ...
# 1002464                  choke
# 1002465                  choke
# 1002466  blackadder-back-forth
# 1002467  blackadder-back-forth
# 1002468  blackadder-back-forth
#
#                                               rtPictureURL  user_id  rating  \
# 0        http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 1        http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 2        http://content7.flixster.com/movie/10/93/63/10...   1339.0     5.0
# 3        http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5
# 4        http://content7.flixster.com/movie/10/93/63/10...    551.0     3.5
# ...                                                    ...      ...     ...
# 1002464  http://content6.flixster.com/movie/10/85/09/10...   1273.0     3.0
# 1002465  http://content6.flixster.com/movie/10/85/09/10...    599.0     3.5
# 1002466  http://content7.flixster.com/movie/34/10/69/34...   1059.0     4.0
# 1002467  http://content7.flixster.com/movie/34/10/69/34...    480.0     5.0
# 1002468  http://content7.flixster.com/movie/34/10/69/34...   1228.0     3.0
#
#          ...                                               Plot Language  \
# 0        ...  A cowboy doll is profoundly threatened and jea...  English
# 1        ...  A cowboy doll is profoundly threatened and jea...  English
# 2        ...  A cowboy doll is profoundly threatened and jea...  English
# 3        ...  A cowboy doll is profoundly threatened and jea...  English
# 4        ...  A cowboy doll is profoundly threatened and jea...  English
# ...      ...                                                ...      ...
# 1002464  ...  A sex-addicted con-man pays for his mother's h...  English
# 1002465  ...  A sex-addicted con-man pays for his mother's h...  English
# 1002466  ...  At a New Millennium Eve party, Blackadder and ...  English
# 1002467  ...  At a New Millennium Eve party, Blackadder and ...  English
# 1002468  ...  At a New Millennium Eve party, Blackadder and ...  English
#
#         Country                                             Awards Metascore  \
# 0           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0
# 1           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0
# 2           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0
# 3           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0
# 4           USA  Nominated for 3 Oscars. Another 27 wins & 20 n...      95.0
# ...         ...                                                ...       ...
# 1002464     USA                            2 wins & 7 nominations.      47.0
# 1002465     USA                            2 wins & 7 nominations.      47.0
# 1002466      UK                                      1 nomination.       NaN
# 1002467      UK                                      1 nomination.       NaN
# 1002468      UK                                      1 nomination.       NaN
#
#         imdbRating imdbVotes Internet Movie Database Rotten Tomatoes  \
# 0              8.3   852,896                     8.3           100.0
# 1              8.3   852,896                     8.3           100.0
# 2              8.3   852,896                     8.3           100.0
# 3              8.3   852,896                     8.3           100.0
# 4              8.3   852,896                     8.3           100.0
# ...            ...       ...                     ...             ...
# 1002464        6.4    31,058                     6.4            55.0
# 1002465        6.4    31,058                     6.4            55.0
# 1002466        7.7    13,510                     7.7             NaN
# 1002467        7.7    13,510                     7.7             NaN
# 1002468        7.7    13,510                     7.7             NaN
#
#         Metacritic
# 0             95.0
# 1             95.0
# 2             95.0
# 3             95.0
# 4             95.0
# ...            ...
# 1002464       47.0
# 1002465       47.0
# 1002466        NaN
# 1002467        NaN
# 1002468        NaN
#
# [1002469 rows x 29 columns]

# %%
# Remove all other useless rows with too many NaNs
# Remove double/multiple ratings of same users
# Check if all movies are merged under the same omdbID
# Print out data into ../data/preprocessed folder
# Duild dataframe/csv with average rating for each omdbID
